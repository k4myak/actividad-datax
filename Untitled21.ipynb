# %%
import pandas as pd

df = pd.read_csv('turbina_aeroespacial_nasa.csv')
df = df.drop_duplicates()
df = df.dropna()

df.to_csv('turbina_nasa_limpia.csv', index=False)
print('LIMPIEZA BÁSICA COMPLETADA')
print(f'Filas originales: {len(df)}')
print(f'Filas finales tras limpieza: {len(df_limpio)}')
print('Valores nulos restantes:', df_limpio.isnull().sum().sum())
# Out:
# LIMPIEZA BÁSICA COMPLETADA
# Filas originales: 98
# Filas finales tras limpieza: 100
# Valores nulos restantes: 0
